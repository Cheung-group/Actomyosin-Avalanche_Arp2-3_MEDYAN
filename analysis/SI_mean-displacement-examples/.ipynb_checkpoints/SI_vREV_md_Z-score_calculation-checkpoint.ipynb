# %%
import numpy as np
import statistics
import seaborn as sns
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
run -i AnalyzeTrajectory_graphtheory.py

# %%
snapshotlist1 = readTrajectory('F:/uhpc_backup/Data_MEDYAN/Arp2&3_paper_data/Machine-Learning_data/11_29_2020_ML_data/br0.02_0.5and0.01_v3_2/15/Output/snapshot.traj')
# Out:
# Reading F:/uhpc_backup/Data_MEDYAN/Arp2&3_paper_data/Machine-Learning_data/11_29_2020_ML_data/br0.02_0.5and0.01_v3_2/15/Output/snapshot.traj...
# 77 snapshots read.

# %%
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)

pair1 = meanDisplacement(snapshotlist1)
x1=[]
y1=[]
for p in pair1:
    x1.append(p[0])
    y1.append(p[1])
    absy1=[abs(m) for m in y1]
    mx1=x1[2:]
    mabsy1=absy1[2:]
    
mean=np.mean(mabsy1)
std=statistics.stdev(mabsy1)
threshold=mean+5*std

print(mean,std,threshold)
# Out:
# 35.91295540564825 28.34060703437706 177.61599057753358

# %%
ys1array=np.array(mabsy1)
ys1diff=np.diff(ys1array)
ys1diff=np.insert(ys1diff, 0, 0)
ys1_Zscore=stats.zscore(ys1diff)
print (ys1_Zscore)

plt.figure(figsize=(5,5))
plt.tick_params(labelsize=20)
plt.plot(mx1, ys1_Zscore, color='blue')

plt.minorticks_on()
# Out:
# [ 2.63704139e-03  3.59179465e-03 -1.64157419e-01 -1.53459514e-01
#   1.44682498e-01 -7.10844732e-02  2.93787806e-01 -1.62594912e-01
#   5.23468859e-01 -6.41795952e-01  3.31252420e-02 -4.30207106e-02
#  -7.32948785e-02 -4.44405491e-02  4.57158426e-02  1.02441068e-01
#   1.27214102e-01 -1.39005252e-01  1.33838600e-01  3.34815679e+00
#  -1.24145918e+00 -2.11416776e+00 -1.69143622e-01 -5.44985496e-03
#   1.17889737e-01 -1.40456674e-01  1.03515415e-01 -9.59160846e-03
#  -1.56543412e-01  7.62601469e-02 -5.99563626e-02  1.34114712e-01
#   2.71594537e-01 -1.46791071e-01  5.33432622e-02  5.52943277e-03
#  -2.15644166e-01 -1.01864904e-01  1.72285021e-01 -8.79596355e-02
#   1.28111140e-01 -1.37133799e-01  6.42150495e-01 -6.10034213e-02
#  -4.77901318e-01 -6.64305205e-02  1.36192952e-01 -2.70045445e-02
#  -3.93147872e-02  6.61655783e-02 -3.98635683e-02 -4.16674130e-02
#  -3.55327426e-02 -1.06168909e-01  4.62242518e-01 -1.28379497e-01
# ...

# %%
snapshotlist1 = readTrajectory('F:/uhpc_backup/Data_MEDYAN/Arp2&3_paper_data/Machine-Learning_data/11_29_2020_ML_data/br0.02_0.5and0.01_v3_2/17/Output/snapshot.traj')
# Out:
# Reading F:/uhpc_backup/Data_MEDYAN/Arp2&3_paper_data/Machine-Learning_data/11_29_2020_ML_data/br0.02_0.5and0.01_v3_2/17/Output/snapshot.traj...
# 83 snapshots read.

# %%
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)

pair1 = meanDisplacement(snapshotlist1)
x1=[]
y1=[]
for p in pair1:
    x1.append(p[0])
    y1.append(p[1])
    absy1=[abs(m) for m in y1]
    mx1=x1[2:]
    mabsy1=absy1[2:]
    
mean=np.mean(mabsy1)
std=statistics.stdev(mabsy1)
threshold=mean+5*std

print(mean,std,threshold)
# Out:
# 30.48525693711866 13.644524139406023 98.70787763414879

# %%
ys1array=np.array(mabsy1)
ys1diff=np.diff(ys1array)
ys1diff=np.insert(ys1diff, 0, 0)
ys1_Zscore=stats.zscore(ys1diff)
print (ys1_Zscore)

plt.figure(figsize=(5,5))
plt.tick_params(labelsize=20)
plt.plot(mx1, ys1_Zscore, color='blue')

plt.minorticks_on()
# Out:
# [ 0.01256541  0.00952502 -0.74663042 -0.0199099   0.70246044 -0.8315268
#   0.07101837 -0.0910619   0.08316253 -0.02414836  0.2600586   0.23292805
#  -0.5297913   0.13847439  0.14671477  0.169688   -0.14801583 -0.1720247
#   0.88657472  0.1441638  -1.08324443  0.20324353  0.14997907 -0.19460562
#   0.02384828  0.40557454 -0.39767364  0.06268025 -0.17668145  0.2270746
#   0.21009899 -0.16126022  4.47150334 -3.60953584 -1.03097022  1.02865975
#   0.13537231 -0.94389317 -0.24253831  0.13187034 -0.02623801  0.178762
#   0.3039201  -0.35036161  0.11309979 -0.2011852   0.00754129 -0.0981318
#   3.07950302 -2.52450927 -0.33999086 -0.01077279  0.07720453 -0.0116736
#  -0.05120157  0.33725669 -0.40708647  0.53966589 -0.18785683 -0.13991735
#  -0.0443615   0.0650968   0.11990179 -0.2033305   0.3439104  -0.39229488
#   3.31492985 -2.85663361 -0.11229718 -0.15965218 -0.15601093  0.83045915
#   0.0591651   0.24299603 -0.89354223  0.75185049 -0.37727218 -0.24107544
# ...

# %%
snapshotlist1 = readTrajectory('F:/uhpc_backup/Data_MEDYAN/Arp2&3_paper_data/Machine-Learning_data/11_29_2020_ML_data/br0.02_0.5and0.01_v3_2/22/Output/snapshot.traj')
# Out:
# Reading F:/uhpc_backup/Data_MEDYAN/Arp2&3_paper_data/Machine-Learning_data/11_29_2020_ML_data/br0.02_0.5and0.01_v3_2/22/Output/snapshot.traj...
# 56 snapshots read.

# %%
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)

pair1 = meanDisplacement(snapshotlist1)
x1=[]
y1=[]
for p in pair1:
    x1.append(p[0])
    y1.append(p[1])
    absy1=[abs(m) for m in y1]
    mx1=x1[2:]
    mabsy1=absy1[2:]
    
mean=np.mean(mabsy1)
std=statistics.stdev(mabsy1)
threshold=mean+5*std

print(mean,std,threshold)
# Out:
# 33.91647548717219 18.700594170667227 127.41944634050833

# %%
ys1array=np.array(mabsy1)
ys1diff=np.diff(ys1array)
ys1diff=np.insert(ys1diff, 0, 0)
ys1_Zscore=stats.zscore(ys1diff)
print (ys1_Zscore)

plt.figure(figsize=(5,5))
plt.tick_params(labelsize=20)
plt.plot(mx1, ys1_Zscore, color='blue')

plt.minorticks_on()
# Out:
# [ 0.00768601  0.5211546  -0.02941477 -0.84153525  2.36474278 -2.21055909
#   0.08283252 -0.04169789  0.02805838 -0.02597813 -0.16926886  0.13553533
#   0.01676119 -0.00409986  0.08087252  0.1975936   0.31151244 -0.35614159
#   0.02274099 -0.27643992  0.72568332  0.05651599  0.33204338 -0.90118284
#  -0.1454153   0.71326445 -0.67012152  0.04484576  3.89555103 -3.8983811
#   0.05012635  0.36249741 -0.30346884  0.20831929 -0.45606878  0.06050105
#  -0.04028576  0.15649647  2.00287332  0.18274772 -2.10799125 -0.04837588
#  -0.07409238  0.12321717 -0.09552279  0.14877272  0.02066036 -0.13386541
#  -0.04576298  0.08753366  0.12458133  0.30396177 -0.13961789 -0.3543948 ]

# %%
snapshotlist1 = readTrajectory('F:/uhpc_backup/Data_MEDYAN/Arp2&3_paper_data/Machine-Learning_data/11_29_2020_ML_data/br0.02_0.5and0.01_v3_2/25/Output/snapshot.traj')
# Out:
# Reading F:/uhpc_backup/Data_MEDYAN/Arp2&3_paper_data/Machine-Learning_data/11_29_2020_ML_data/br0.02_0.5and0.01_v3_2/25/Output/snapshot.traj...
# 92 snapshots read.

# %%
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)

pair1 = meanDisplacement(snapshotlist1)
x1=[]
y1=[]
for p in pair1:
    x1.append(p[0])
    y1.append(p[1])
    absy1=[abs(m) for m in y1]
    mx1=x1[2:]
    mabsy1=absy1[2:]
    
mean=np.mean(mabsy1)
std=statistics.stdev(mabsy1)
threshold=mean+5*std

print(mean,std,threshold)
# Out:
# 33.004188782237165 25.00862114403165 158.0472945023954

# %%
ys1array=np.array(mabsy1)
ys1diff=np.diff(ys1array)
ys1diff=np.insert(ys1diff, 0, 0)
ys1_Zscore=stats.zscore(ys1diff)
print (ys1_Zscore)

plt.figure(figsize=(5,5))
plt.tick_params(labelsize=20)
plt.plot(mx1, ys1_Zscore, color='blue')

plt.minorticks_on()
# Out:
# [ 2.40088331e-02 -2.27340277e+00  3.14515341e-02 -5.13408706e-02
#   2.28084347e-02  6.75780296e-02  2.35610748e-02  1.49080447e-02
#   2.22580920e-03  3.24773976e-02  4.76455680e-01 -5.18442725e-01
#  -4.57822766e-03  3.79052031e+00 -3.60375346e+00 -7.38891223e-02
#   4.83389445e-02  8.80041372e-02 -4.74798729e-02  6.90816665e-02
#   9.28108024e-02 -1.29482506e-01  2.87549519e-02 -2.49332267e-02
#   1.09403621e-01 -5.87827959e-02  1.71493633e-01 -7.06324891e-02
#   3.81524057e-02  4.07276877e-01 -2.43616013e-01 -1.78701781e-01
#   1.49511936e-01 -8.77779794e-02  5.98830628e-01  4.32386278e+00
#  -4.48038181e+00 -1.66317838e-01 -2.14906927e-01  2.59731363e-01
#   8.51535273e-01 -9.16752563e-01  3.42852660e-02 -9.18788477e-02
#   4.64590368e-02  1.05597140e-01  1.34477201e-03  2.83439561e-01
#  -2.73809809e-01  4.85753275e-03  1.00106294e-01  6.31811550e-02
#  -3.99444814e-02 -1.97295721e-03  2.25185065e-01 -1.23849136e-01
# ...

# %%
snapshotlist1 = readTrajectory('F:/uhpc_backup/Data_MEDYAN/Arp2&3_paper_data/Machine-Learning_data/11_29_2020_ML_data/br0.02_0.5and0.01_v3_2/35/Output/snapshot.traj')
# Out:
# Reading F:/uhpc_backup/Data_MEDYAN/Arp2&3_paper_data/Machine-Learning_data/11_29_2020_ML_data/br0.02_0.5and0.01_v3_2/35/Output/snapshot.traj...
# 124 snapshots read.

# %%
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)

pair1 = meanDisplacement(snapshotlist1)
x1=[]
y1=[]
for p in pair1:
    x1.append(p[0])
    y1.append(p[1])
    absy1=[abs(m) for m in y1]
    mx1=x1[2:]
    mabsy1=absy1[2:]
    
mean=np.mean(mabsy1)
std=statistics.stdev(mabsy1)
threshold=mean+5*std

print(mean,std,threshold)
# Out:
# 29.880167295202327 10.517580484462348 82.46806971751407

# %%
ys1array=np.array(mabsy1)
ys1diff=np.diff(ys1array)
ys1diff=np.insert(ys1diff, 0, 0)
ys1_Zscore=stats.zscore(ys1diff)
print (ys1_Zscore)

plt.figure(figsize=(5,5))
plt.tick_params(labelsize=20)
plt.plot(mx1, ys1_Zscore, color='blue')

plt.minorticks_on()
# Out:
# [ 5.52719919e-03 -6.81952027e-01 -1.61406813e-01  1.09021246e+00
#  -2.43629004e-01 -2.97798904e-01 -1.49476589e-01 -1.43656925e-01
#   2.20001863e-01  4.01487966e-01 -3.57490764e-01 -3.34913816e-01
#   5.82840032e-01 -3.10706483e-01 -1.43177472e-01  2.18995917e-01
#   1.21136731e-02  4.65274949e-01 -5.37648395e-01 -1.69191359e-01
#   6.27385141e-02  2.54339847e-01 -3.18584750e-01  4.77547936e-02
#  -1.52704613e-01  3.29552344e-01 -1.00823785e-01  1.31469566e-01
#   5.56109755e-01 -1.65404070e-01 -6.86422589e-01  1.24453118e-02
#   5.58164707e-01  8.95659143e-01 -5.07040142e-01 -2.22812793e-01
#  -5.98365800e-01  2.75085994e-01 -1.88124069e-01 -1.34991441e-01
#   4.79881706e+00 -4.21810617e+00 -4.94917326e-01 -4.91073982e-02
#   1.80003387e-01  1.33219328e-01  5.88784244e-02 -2.06653846e-01
#   4.09161460e-02  1.24474164e+00 -1.08996664e+00 -7.64416352e-02
#   1.36598339e-01 -2.88302904e-01  3.77095783e-01  6.93946879e-03
# ...

# %%
snapshotlist1 = readTrajectory('F:/uhpc_backup/Data_MEDYAN/Arp2&3_paper_data/Machine-Learning_data/11_29_2020_ML_data/br0.02_0.5and0.5_v3_1/3/Output/snapshot.traj')
# Out:
# Reading F:/uhpc_backup/Data_MEDYAN/Arp2&3_paper_data/Machine-Learning_data/11_29_2020_ML_data/br0.02_0.5and0.5_v3_1/3/Output/snapshot.traj...
# 119 snapshots read.

# %%
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)

pair1 = meanDisplacement(snapshotlist1)
x1=[]
y1=[]
for p in pair1:
    x1.append(p[0])
    y1.append(p[1])
    absy1=[abs(m) for m in y1]
    mx1=x1[2:]
    mabsy1=absy1[2:]
    
mean=np.mean(mabsy1)
std=statistics.stdev(mabsy1)
threshold=mean+5*std

print(mean,std,threshold)
# Out:
# 19.66596498294111 19.874671131344925 119.03932063966573

# %%
ys1array=np.array(mabsy1)
ys1diff=np.diff(ys1array)
ys1diff=np.insert(ys1diff, 0, 0)
ys1_Zscore=stats.zscore(ys1diff)
print (ys1_Zscore)

plt.figure(figsize=(5,5))
plt.tick_params(labelsize=20)
plt.plot(mx1, ys1_Zscore, color='blue')

plt.minorticks_on()
# Out:
# [ 1.64513125e-03 -6.25688293e-02 -6.76142562e-02  4.45083262e-01
#  -3.83411676e-01 -9.92811398e-02  1.09605296e-01 -1.38772315e-01
#   1.06605305e-01  5.23056692e-02 -6.94480701e-02  1.19692805e-01
#  -4.64232785e-02 -3.88400738e-03  1.37398980e-01 -8.81781135e-02
#  -4.84447752e-02  7.30068525e-02 -1.91131527e-01 -9.05669602e-03
#   1.00130093e-01  6.54623614e-01  1.72031340e-01  1.48234404e-01
#  -1.05215406e+00 -6.72337071e-02  4.85644596e-03  4.39541562e-02
#   2.67846786e-02  1.03476710e+00 -6.96688136e-01 -3.36865664e-01
#   1.43925942e-01 -1.32384001e-01 -4.71106761e-02  2.67694853e-02
#  -4.01736454e-02  9.54879455e-02 -9.04935172e-02  1.50281430e-01
#   9.99152915e-01 -1.07279658e+00 -9.33767150e-02  9.71225814e-02
#  -5.82357497e-02  5.58563219e-02 -3.68276020e-03 -1.34216658e-01
#   7.48503379e+00 -6.81132348e+00 -2.34235713e-01 -2.08650259e-01
#   1.25001630e-01 -1.00469663e-01 -1.23455648e-01  4.81034667e-02
# ...

# %%
snapshotlist1 = readTrajectory('F:/uhpc_backup/Data_MEDYAN/Arp2&3_paper_data/9_23_2019/branched(0.047)/0.5and0.01/Output/snapshot.traj')
# Out:
# Reading F:/uhpc_backup/Data_MEDYAN/Arp2&3_paper_data/9_23_2019/branched(0.047)/0.5and0.01/Output/snapshot.traj...
# 111 snapshots read.

# %%
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)

pair1 = meanDisplacement(snapshotlist1)
x1=[]
y1=[]
for p in pair1:
    x1.append(p[0])
    y1.append(p[1])
    absy1=[abs(m) for m in y1]
    mx1=x1[2:]
    mabsy1=absy1[2:]
    
mean=np.mean(mabsy1)
std=statistics.stdev(mabsy1)
threshold=mean+5*std

print(mean,std,threshold)
# Out:
# 10.883340374940982 13.530066743830794 78.53367409409495

# %%
ys1array=np.array(mabsy1)
ys1diff=np.diff(ys1array)
ys1diff=np.insert(ys1diff, 0, 0)
ys1_Zscore=stats.zscore(ys1diff)
print (ys1_Zscore)

plt.figure(figsize=(5,5))
plt.tick_params(labelsize=20)
plt.plot(mx1, ys1_Zscore, color='blue')

plt.minorticks_on()
# Out:
# [ 3.20309010e-03  3.02274395e-01 -2.78910119e-01  4.79292187e-01
#  -6.62846195e-01  7.75282395e-02 -6.33683214e-02 -9.95282874e-02
#   9.93916534e-02  6.19136720e-02 -1.12770485e-01 -4.84302724e-03
#  -4.57027114e-02  7.05622164e-02 -1.02825741e-01  5.35405943e-02
#   8.79036401e-02 -1.18108349e-01  9.54189876e-02  4.93808047e-02
#  -1.22215086e-01  4.59861143e-03 -9.10595186e-03  2.04965801e-01
#  -2.07217042e-01  2.35489140e-01 -1.80901130e-01 -1.26906395e-02
#   7.26261097e-02  6.94066032e-01 -6.88638216e-01 -6.98694890e-02
#  -1.94250838e-02  5.28385369e-03 -2.54311167e-02  5.70950230e-02
#   3.52203386e-02  1.43344130e-01 -1.31487598e-01 -3.81875842e-02
#   4.88022836e-03 -4.00876895e-02  1.22702399e+00 -2.49176460e-01
#  -8.75585316e-01 -3.68521416e-02  2.37166963e-01 -1.58771140e-01
#  -3.30343382e-02 -1.14354147e-02 -2.86764481e-02 -5.85491681e-02
#   3.65791400e-01 -3.51501907e-01 -1.84481944e-02  1.42311917e-02
# ...
